# %%
import pandas as pd
import numpy as np

# %%
df_sample = pd.read_csv('WSMC_HAR_V0_data_sample.txt', sep='\t')

# %%
df_sample
# Out:
#        user-id      time    activity  x-acceleration   y-accel   z-accel
# 0            6  14:51:30  Downstairs        0.517502  0.381622  0.144306
# 1            6  14:51:30  Downstairs        0.491000  0.342433  0.164449
# 2            6  14:51:30  Downstairs        0.475275  0.318269  0.185218
# 3            6  14:51:30  Downstairs        0.464582  0.304869  0.204284
# 4            6  14:51:30  Downstairs        0.451067  0.302467  0.223013
# ...        ...       ...         ...             ...       ...       ...
# 77814        7  13:11:45     Sitting        0.535010  0.523330  0.924100
# 77815        7  13:11:45     Sitting        0.534989  0.523474  0.924028
# 77816        7  13:11:45     Sitting        0.535167  0.523542  0.924015
# 77817        7  13:11:45     Sitting        0.535521  0.523409  0.924227
# 77818        7  13:11:45     Sitting        0.535072  0.523555  0.923977
#
# [77819 rows x 6 columns]
